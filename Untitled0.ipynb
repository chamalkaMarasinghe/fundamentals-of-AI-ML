# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#content/drive/myDrive/chamalaka files/57.png
from PIL import Image
myImg = Image.open("57.png")
display(myImg)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=6250x4419>

# %% [markdown]
# great!

# %%
#pip list - display all installed packages
#convert csv file into raw format in github and take the url of it
import pandas as pd
url = "https://raw.githubusercontent.com/chamalkaMarasinghe/sample-data/main/dataset.csv"

dataFile = pd.read_csv(url)
dataFile.head()
# Out:
#        name  age  marks
# 0  chamalka   23     50
# 1     kamal   23     60
# 2     nimal   24     70
# 3    perera   30     30
